# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('sonar.csv')
dataset.head(10)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 5  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 6  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 7  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 8  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 9  0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
#
#    0.2111 ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  0.0090  \
# ...

# %%
dataset_dummies = pd.get_dummies(data=dataset, columns=['R'],drop_first=True)
dataset_dummies.head(10)
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 5  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 6  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 7  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 8  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 9  0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
#
#    0.2111 ...   0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872 ...   0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# ...

# %%
y = dataset_dummies.loc[:, ["R_R"]].values
dataset_dummies.drop(["R_R"], axis=1, inplace=True)
X = dataset_dummies.iloc[:, 0:].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
classifier.add(Dense(units = 55, kernel_initializer = 'uniform', activation = 'relu', input_dim = 60))
classifier.add(Dense(units = 34, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 2, epochs = 20)
# Out:
# Epoch 1/20
# 165/165 [==============================] - 1s 4ms/step - loss: 0.6700 - acc: 0.7212
# Epoch 2/20
# 165/165 [==============================] - 0s 636us/step - loss: 0.4419 - acc: 0.8424
# Epoch 3/20
# 165/165 [==============================] - 0s 679us/step - loss: 0.2568 - acc: 0.9152
# Epoch 4/20
# 165/165 [==============================] - 0s 709us/step - loss: 0.1916 - acc: 0.9212
# Epoch 5/20
# 165/165 [==============================] - 0s 791us/step - loss: 0.1219 - acc: 0.9515
# Epoch 6/20
# 165/165 [==============================] - 0s 691us/step - loss: 0.0827 - acc: 0.9697
# Epoch 7/20
# 165/165 [==============================] - 0s 746us/step - loss: 0.0468 - acc: 0.9879
# Epoch 8/20
# 165/165 [==============================] - 0s 730us/step - loss: 0.0298 - acc: 1.0000
# Epoch 9/20
# 165/165 [==============================] - 0s 655us/step - loss: 0.0129 - acc: 1.0000
# Epoch 10/20
# ...

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix
y_pred_category = (y_pred > 0.3)
cm = confusion_matrix(y_test, y_pred_category)
cm
# Out:
# array([[19,  3],
#        [ 5, 15]], dtype=int64)
